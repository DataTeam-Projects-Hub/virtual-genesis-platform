# %%
from pymongo import MongoClient
from collections import deque, defaultdict

# Connect to MongoDB
client = MongoClient(os.getenv("MONGO_URI"))
db = client["virtualgenesis"]  

collection_name = "jarvis_swap"
token_name = "JARVIS"
collection = db[collection_name]

# Fetch and sort transactions
cursor = collection.find().sort("timestamp", 1)
trades_by_maker = defaultdict(list)

# Prepare trade data grouped by trader
for doc in cursor:
    maker = doc.get("maker")
    swap_type = doc.get("swapType")
    try:
        price = float(doc.get("genesis_usdc_price", 0))
    except (TypeError, ValueError):
        continue

    if not price or not maker:
        continue

    if swap_type == "buy":
        try:
            # What user pays for (before tax) - full purchase amount
            amount_bought_before_tax = float(doc.get("JARVIS_OUT_BeforeTax", 0))
            # What user actually receives in wallet (after tax)
            amount_received = float(doc.get("JARVIS_OUT_AfterTax", 0))
        except (TypeError, ValueError):
            continue
        
        if amount_bought_before_tax <= 0:
            continue
            
        trades_by_maker[maker].append({
            'type': 'buy',
            'amount_bought_before_tax': amount_bought_before_tax,  # What user paid for
            'amount_received': amount_received,  # Actual tokens in wallet
            'price': price
        })

    elif swap_type == "sell":
        try:
            # What user actually gets proceeds from (after tax deduction)
            amount_sold_net = float(doc.get("JARVIS_IN_AfterTax", 0))
            # What actually left user's wallet (before tax or after tax + tax)
            amount_from_wallet = float(doc.get("JARVIS_IN_BeforeTax", 0))
        except (TypeError, ValueError):
            continue
            
        if amount_sold_net <= 0:
            continue
            
        trades_by_maker[maker].append({
            'type': 'sell',
            'amount_sold_net': amount_sold_net,  # Net proceeds after tax
            'amount_from_wallet': amount_from_wallet,  # Tokens that left wallet
            'price': price
        })

# Store final results
results = []

# Calculate PnL per trader
for maker, trades in trades_by_maker.items():
    buy_queue = deque()  # Stores tokens actually received (after tax)
    total_realized_pnl = 0.0

    for trade in trades:
        if trade['type'] == 'buy':
            # Store actual tokens received (what's in wallet)
            buy_queue.append({
                'amount': trade['amount_received'],  # Tokens actually in wallet
                'amount_paid_for': trade['amount_bought_before_tax'],  # What user paid for
                'price': trade['price']
            })

        elif trade['type'] == 'sell':
            amount_from_wallet = trade['amount_from_wallet']  # Tokens leaving wallet
            amount_sold_net = trade['amount_sold_net']  # Net proceeds after tax
            sell_price = trade['price']

            # Match against oldest buys (FIFO) - match what's leaving wallet
            remaining_to_match = amount_from_wallet
            
            while remaining_to_match > 0 and buy_queue:
                buy = buy_queue.popleft()
                buy_amount_in_wallet = buy['amount']  # Tokens actually owned
                buy_amount_paid_for = buy['amount_paid_for']  # What user originally paid for
                buy_price = buy['price']

                # How much can we match?
                matched_amount_in_wallet = min(remaining_to_match, buy_amount_in_wallet)
                
                # Calculate the corresponding amount user originally paid for
                ratio = matched_amount_in_wallet / buy_amount_in_wallet
                matched_amount_paid_for = buy_amount_paid_for * ratio

                # PnL = What user paid for - What user gets from selling
                # User paid: matched_amount_paid_for × buy_price
                # User gets: (matched_amount_in_wallet / amount_from_wallet) × amount_sold_net × sell_price
                proceeds_ratio = matched_amount_in_wallet / amount_from_wallet
                actual_proceeds = amount_sold_net * sell_price * proceeds_ratio
                cost_paid = matched_amount_paid_for * buy_price
                
                pnl = actual_proceeds - cost_paid
                total_realized_pnl += pnl

                # Update remaining amounts
                remaining_to_match -= matched_amount_in_wallet
                remaining_buy_amount = buy_amount_in_wallet - matched_amount_in_wallet

                # If buy order partially filled, put remainder back
                if remaining_buy_amount > 0:
                    remaining_paid_for = buy_amount_paid_for * (remaining_buy_amount / buy_amount_in_wallet)
                    buy_queue.appendleft({
                        'amount': remaining_buy_amount,
                        'amount_paid_for': remaining_paid_for,
                        'price': buy_price
                    })

    # Calculate remaining inventory (tokens still held)
    remaining_tokens = sum(b['amount'] for b in buy_queue)

    results.append({
        'trader': maker,
        'token': token_name,
        'net_pnl': round(total_realized_pnl, 4),
        'remaining_tokens': round(remaining_tokens, 4)
    })

# Print results
for row in results:
    print("="*60)
    print(f"Trader: {row['trader']}")
    print(f"Token: {row['token']}")
    print(f"Net PnL: ${row['net_pnl']}")
    print(f"Remaining Tokens: {row['remaining_tokens']}")
    print("="*60)
# Out:
# ============================================================
# Trader: 0x6acA0AEFA3CF63a67282a26B8E3Db08e03c9483C
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 15292674.6132
# ============================================================
# ============================================================
# Trader: 0x4240398c6a07147B062376e4a0A8562F8340c12D
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 5678699.7276
# ============================================================
# ============================================================
# Trader: 0xE798045BECBBdCe8031d28e8E61Cb3c56e6Ee8bF
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4879451.0125
# ============================================================
# ============================================================
# Trader: 0x6Fec65619e49378220D9353D8F05f8eA74D93cb6
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 1785663.6475
# ============================================================
# ============================================================
# Trader: 0x0289c426c6804d648427cE2D67C35d4C309a4eC4
# Token: JARVIS
# Net PnL: $-65.4841
# Remaining Tokens: 213.1041
# ============================================================
# ============================================================
# Trader: 0x270028e8CfE2c9D5A8F94c09ced11314999aD019
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 9212.2474
# ============================================================
# ============================================================
# Trader: 0x83fffF6f6bd73c63E162a348b24A762a1cA0361f
# Token: JARVIS
# Net PnL: $-113.2562
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xFA3a8AAf8583872f9961954D5e6Eb88fc697EFC2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4608359.5654
# ============================================================
# ============================================================
# Trader: 0x2B3b2F3C3B1Fa15e26fd5b9ceee2958d07Ffd260
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 186.4138
# ============================================================
# ============================================================
# Trader: 0xf1A14825Ab564B15F77009E9847a1912f2752201
# Token: JARVIS
# Net PnL: $-1.1297
# Remaining Tokens: 12.7395
# ============================================================
# ============================================================
# Trader: 0x994e7aC2D82aA5d7Ea4a1821Bcf657cf9bf06d1c
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 1613.4335
# ============================================================
# ============================================================
# Trader: 0x9A1eE67e454bb963183884e7e2872fc0016613D3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 3020196.6789
# ============================================================
# ============================================================
# Trader: 0xD93Be509e4793f930bCfFC8B5aD35a32E7371A95
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x74Cd4f2364DcD66E0BD9C2F1C43633aBF57F855F
# Token: JARVIS
# Net PnL: $-3.0966
# Remaining Tokens: 3386.6048
# ============================================================
# ============================================================
# Trader: 0xed1341Ff024C42D95D779c64c748201E334ce696
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x37c3a7c8d47df9Cd70c1a0D2c3C833351053b5FE
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 23160.7131
# ============================================================
# ============================================================
# Trader: 0x6F011C1AaE06180A9792e5C457b441b727b18fea
# Token: JARVIS
# Net PnL: $-158.4341
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x7babf08bB0BFF4A8513820Dd70E56b33539BD247
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd3b7d0745EdCE76A3Bd394B1EE5747683dbD8036
# Token: JARVIS
# Net PnL: $-0.0027
# Remaining Tokens: 145.785
# ============================================================
# ============================================================
# Trader: 0x206249BF17E57cEbECb80F4d4B93de8B76dA93c4
# Token: JARVIS
# Net PnL: $48.0182
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x762229E03aC76D5df17447EeF0c3e5caf60D9709
# Token: JARVIS
# Net PnL: $-42.4041
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x8342E9370eddd706D4f1c84Af507B81E2d46eed7
# Token: JARVIS
# Net PnL: $194.447
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x914878dD665Eddb62739902ba8e5b255EcbBE05E
# Token: JARVIS
# Net PnL: $43.0419
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd2c941227F74C6B438DEE86971Ca19537C740cD4
# Token: JARVIS
# Net PnL: $-30.4955
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x43a27d07392af4099953fd88466C94cB7D08D51c
# Token: JARVIS
# Net PnL: $-27.3132
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD69be1bD6CD5df362880C38c98ef12C3CcF8eB9d
# Token: JARVIS
# Net PnL: $-0.0755
# Remaining Tokens: 14.9894
# ============================================================
# ============================================================
# Trader: 0x89c4c3c1EEAb2922626218ce3a5D9B2F52215F2e
# Token: JARVIS
# Net PnL: $36.3046
# Remaining Tokens: 209907.2804
# ============================================================
# ============================================================
# Trader: 0x25323e369f22177563CDAB6c7b31a10B3d6d8d6F
# Token: JARVIS
# Net PnL: $102.74
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xbEFba576BfEfFA837b121C46DecbD4b6AfB2DD52
# Token: JARVIS
# Net PnL: $3.1368
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1B3d7FF4943Ad0e8cBa59793f28e20974cA2083A
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x861321411e7151a77EC330D3CcA0e979E21DFF58
# Token: JARVIS
# Net PnL: $2.9729
# Remaining Tokens: 7.7394
# ============================================================
# ============================================================
# Trader: 0x8b8c6fc3e47c7b0242DaeE0C9e4D8c5C09068b70
# Token: JARVIS
# Net PnL: $-0.1743
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x55eEA85F4619662F48Ca3754df25BB4dACa78208
# Token: JARVIS
# Net PnL: $22.6398
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3448075BaE1be475052283680346ba159aD91C54
# Token: JARVIS
# Net PnL: $1.0373
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xdeF8E8b4e43a6179462896a6BCfa21F4449F5397
# Token: JARVIS
# Net PnL: $141.6012
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd98F463F3Fd46BCAbFCF4a0d6901BC8d9F384d57
# Token: JARVIS
# Net PnL: $-20.3098
# Remaining Tokens: 1913.2279
# ============================================================
# ============================================================
# Trader: 0x28530124A05b99d1c63B7F41F856a4c9b6D9aaDb
# Token: JARVIS
# Net PnL: $-0.3928
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xbFE4c98a240b1f86AB1D1F62270c408Af0b1a608
# Token: JARVIS
# Net PnL: $25.1149
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x895A1154D8Bf767855ea95b610f6c1772996d3e6
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4061.7017
# ============================================================
# ============================================================
# Trader: 0x0ebB26DF830DE59aa149F6a52fe4060fD5C221FB
# Token: JARVIS
# Net PnL: $515.8752
# Remaining Tokens: 1676878.4964
# ============================================================
# ============================================================
# Trader: 0x4A10277e2bc247957F725454Fbab463518F295b2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x11849573966d4a16C2196D32e79164087b23E202
# Token: JARVIS
# Net PnL: $-0.0064
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3eBf0C268E5ba5Efc9DAa75D68FA13B4BE5475ec
# Token: JARVIS
# Net PnL: $-8.5101
# Remaining Tokens: 2907.8506
# ============================================================
# ============================================================
# Trader: 0x2e8898A707Cd22330c73475510a5c53D89efcb93
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1E562BF73369D1d5B7E547b8580039E1f05cCc56
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xc44f454cA2D814CF86333F6fd30476B6E6475712
# Token: JARVIS
# Net PnL: $28.3904
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x954C4eD746e8294F522D91f9C4a3c552254817c7
# Token: JARVIS
# Net PnL: $25.8048
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xaF6a663dE084aA6261A39D5C1a05782fDa1a837d
# Token: JARVIS
# Net PnL: $-275.3129
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x330D1D5A5B29E9707c502638a8a6f8Ab10001917
# Token: JARVIS
# Net PnL: $43.6008
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x660e3a3d4725433493824c84b58322EEb92d6F96
# Token: JARVIS
# Net PnL: $12.8801
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xEA7e4cBE5dD1C54414eDF001274147339349C805
# Token: JARVIS
# Net PnL: $-11.6758
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x74E121599DB43F2b11b75179aaF06F5ED6187977
# Token: JARVIS
# Net PnL: $-143.7153
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xE05813988B62830B32ff92CBBBA5607F61ec1Be2
# Token: JARVIS
# Net PnL: $4.0261
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xEceb3ddA403e297F0f888D67b637C06448cA4848
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 817717.7832
# ============================================================
# ============================================================
# Trader: 0x998bCEC3b4EE1084b267153319533e37dA36BA70
# Token: JARVIS
# Net PnL: $-51.6401
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x52d3FD84b61b2C1cddECCb51832aD24F4d473f96
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xB719a31208C7D96f7260eF710755f6b5ECB59036
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4669.8965
# ============================================================
# ============================================================
# Trader: 0x997BA1a78C72F2139E038eAF868f859a5B22c4D0
# Token: JARVIS
# Net PnL: $-228.5547
# Remaining Tokens: 1955.0984
# ============================================================
# ============================================================
# Trader: 0x5b6d3F6d59F5FE8957A42259862b5959C1888b28
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2315.3826
# ============================================================
# ============================================================
# Trader: 0x31d94F29e21e1B6f450CAC1dDf97c9053797FA10
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2315.2855
# ============================================================
# ============================================================
# Trader: 0x0F31B1b200d1BebEeda4b2f205273F4817113f97
# Token: JARVIS
# Net PnL: $169.717
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xE5A160e344801db401e48A462B19a4cF362cFc88
# Token: JARVIS
# Net PnL: $16.4862
# Remaining Tokens: 2254.5385
# ============================================================
# ============================================================
# Trader: 0x36d57818b5E6754Df0E0fA7225bB1001d6E1A259
# Token: JARVIS
# Net PnL: $1.0541
# Remaining Tokens: 306.4384
# ============================================================
# ============================================================
# Trader: 0x580744a9D40Cd99A99F3bE0398476F29C1B54583
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x27cC7F8aF1E799eD75aeB9C2756C6dcC3A495b39
# Token: JARVIS
# Net PnL: $99.2376
# Remaining Tokens: 892946.195
# ============================================================
# ============================================================
# Trader: 0xBAD29a92ca1bEdCD6C17b3917BCD38D71Fd25370
# Token: JARVIS
# Net PnL: $-3.7167
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3699F1C81728B1EE6447C8e9064fa22Df4c88f45
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2260.4232
# ============================================================
# ============================================================
# Trader: 0x0C17e90B95a16BA2b41FbC4E7950E6eba13F85c6
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 81312.9767
# ============================================================
# ============================================================
# Trader: 0x906b3E69717856a6817625Abd3c5A805aEf921cC
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 451.3996
# ============================================================
# ============================================================
# Trader: 0x176987A76d999BF117377aaaA6c2E54c44FCF6f7
# Token: JARVIS
# Net PnL: $6.187
# Remaining Tokens: 27.8497
# ============================================================
# ============================================================
# Trader: 0x70Ce9cf610BdfB9645ed678202aDa4AFa9257087
# Token: JARVIS
# Net PnL: $42.6308
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xb3A6E35B8BcE93BD43c0D870DB7B7664aae027F8
# Token: JARVIS
# Net PnL: $2.9307
# Remaining Tokens: 101.5162
# ============================================================
# ============================================================
# Trader: 0x6f339eF23B09f83e2B43f8DAF83E3313D2FeedA3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4286.9032
# ============================================================
# ============================================================
# Trader: 0x565b3F50e8d17c14760462fa26b8B5C3fD73c09e
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xdEC4788F8c2928ec4e3b5bbC8188428A7b5e1630
# Token: JARVIS
# Net PnL: $30.0861
# Remaining Tokens: 635.0625
# ============================================================
# ============================================================
# Trader: 0x433A28b428A745E4A59829525752100b3396610E
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x282606a2d9BcC5209764d7bCf83a90Af5B04335d
# Token: JARVIS
# Net PnL: $45.3229
# Remaining Tokens: 38563.7339
# ============================================================
# ============================================================
# Trader: 0x2eB529012F1246A1b0d03FAC63B5B4d624513312
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 105615.0229
# ============================================================
# ============================================================
# Trader: 0x9c28d5868B6461C830EEc2AC07D36b39913862Fa
# Token: JARVIS
# Net PnL: $25.8345
# Remaining Tokens: 1227.9358
# ============================================================
# ============================================================
# Trader: 0x7C4A9c56F366aD5283E4fA54F8A6467713CBd9CC
# Token: JARVIS
# Net PnL: $-152.0463
# Remaining Tokens: 8393.8794
# ============================================================
# ============================================================
# Trader: 0x7fE120aBefd9E0eB97f49d7f84f413A7b5ade677
# Token: JARVIS
# Net PnL: $-0.2798
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x07BD4932D08e5956faB224965a58BF1a441134A1
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1ABA272c79a615C1D867828766b8e00a0EDAC010
# Token: JARVIS
# Net PnL: $-19.8668
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x9bA876D431eE78b4b8655E692e6dEe609c0530aE
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x60E483cdCf8Ca76Cb83594675caD74fe3D6F97eC
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4202.3307
# ============================================================
# ============================================================
# Trader: 0x81f2af77fc297e05e59D7d45bC6DDe2c2555061d
# Token: JARVIS
# Net PnL: $10.0609
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x48193Db80BE007E17448fB7E773Bf989bF307749
# Token: JARVIS
# Net PnL: $-19.1835
# Remaining Tokens: 10493.6226
# ============================================================
# ============================================================
# Trader: 0x8d4AEDE5a6A6f1c87b5FEeB07108B208042168A7
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 419.6996
# ============================================================
# ============================================================
# Trader: 0x22d344853f6c1A565b771f75522cF8120571Ed56
# Token: JARVIS
# Net PnL: $-93.3514
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xC73535d30934eb9097aD197Fbc4FE18D8701BfBA
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4a53e4cb9822195eA3c308E54a5AC222D3880fAC
# Token: JARVIS
# Net PnL: $-5.0309
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3D76DA7e85E027D0F768382578E6ABA83B0F224f
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 42.7904
# ============================================================
# ============================================================
# Trader: 0xe0118388D45e783EAA1C3E5E12ed30c333E41Aeb
# Token: JARVIS
# Net PnL: $1.1803
# Remaining Tokens: 836.862
# ============================================================
# ============================================================
# Trader: 0x25605c3fD6eA7f36Ba6BE85aA371f399a9436792
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2652.7211
# ============================================================
# ============================================================
# Trader: 0xe557206B5C3c98C547c222dFD189C27D079F8cc3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 73521.8678
# ============================================================
# ============================================================
# Trader: 0xc3e10c3C1701739EA872bA3960DC1b301b48df54
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4269.3486
# ============================================================
# ============================================================
# Trader: 0x526bDE37e383CA8af632E87C6DF7dBB657115337
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2134.5453
# ============================================================
# ============================================================
# Trader: 0x1333BEa59D910837e790cd3cC7c409bd2c4F8954
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 8537.3224
# ============================================================
# ============================================================
# Trader: 0x917d9764F16161922DF7A7D03fcd530007942CE2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 10669.7198
# ============================================================
# ============================================================
# Trader: 0xf8414FF9C643C5e1000430C66C92a6bBc31c8651
# Token: JARVIS
# Net PnL: $12.2047
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x3f33685783CB30998360b78a369Ff34137e9A214
# Token: JARVIS
# Net PnL: $41.5038
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xEDB969cA0A38D90e4Cf37E42b5eE7BDE314B1312
# Token: JARVIS
# Net PnL: $0.4579
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x69ABD467d5848aa823613Fc6E51977B64495Bf67
# Token: JARVIS
# Net PnL: $3.2077
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xC7e4C4292e0EABD3faa3781c23c01a197fa80173
# Token: JARVIS
# Net PnL: $-1.9053
# Remaining Tokens: 3741.1231
# ============================================================
# ============================================================
# Trader: 0x73192867dc0895ceECA87c8A5c45A4DB334D2C74
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 165599.4468
# ============================================================
# ============================================================
# Trader: 0xEF0C487DE5eB4f756D3372A0EA473b67D7dF7533
# Token: JARVIS
# Net PnL: $2.0093
# Remaining Tokens: 2829.4732
# ============================================================
# ============================================================
# Trader: 0x87F77Acb99B94d6e663574256158A354dD32e457
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x54f339862835D6B0d38D223FAcfb65070125b4f4
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2609567.6709
# ============================================================
# ============================================================
# Trader: 0x45a53C35136a8d170b028DB25935daF69a96130b
# Token: JARVIS
# Net PnL: $6.5188
# Remaining Tokens: 34041.642
# ============================================================
# ============================================================
# Trader: 0x5aEbFE294bB2DA35eEbEe477734F3b4a0930be49
# Token: JARVIS
# Net PnL: $-1.7699
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xC90FB8f96b32D20D80C45cf16F9bec26A8e945Af
# Token: JARVIS
# Net PnL: $0.3059
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1ec25780C7Be0dD9753385E8C67c7b999Cc58C77
# Token: JARVIS
# Net PnL: $0.6917
# Remaining Tokens: 30.9086
# ============================================================
# ============================================================
# Trader: 0x70f4F5F0F69A561eE87135b2bD213Da3Ce8fBf08
# Token: JARVIS
# Net PnL: $-39.6024
# Remaining Tokens: 20558.3022
# ============================================================
# ============================================================
# Trader: 0x002344F3C01b32771936403d2E531c1B4018ECc6
# Token: JARVIS
# Net PnL: $-3.2763
# Remaining Tokens: 20.447
# ============================================================
# ============================================================
# Trader: 0x0c1f250CfC6CB85374937a649D53ba45B910Fbb3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 1930893.5891
# ============================================================
# ============================================================
# Trader: 0x4BdddfCdeF7AE0e77c0C48d3e04bb8eC094c6634
# Token: JARVIS
# Net PnL: $-2.7786
# Remaining Tokens: 412.1409
# ============================================================
# ============================================================
# Trader: 0x4C6dCDcA494A8b41f212b915E1cF2a19E3f17340
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x56542d8dE039403281E8f949c26f331bcfAfEaA1
# Token: JARVIS
# Net PnL: $1.7121
# Remaining Tokens: 1564.8
# ============================================================
# ============================================================
# Trader: 0x326b39ad29df260ce36dEFC3025ae444F2d19438
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 224015.3782
# ============================================================
# ============================================================
# Trader: 0x5763dB43549ba523A163193898E397DC840A32AE
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 1667671.1562
# ============================================================
# ============================================================
# Trader: 0xbeE3717cCE30e95cc3f4E1A8b52E47F3b5F69D27
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 423716.6499
# ============================================================
# ============================================================
# Trader: 0x9BAFe8d03D5393A34483A5Fe6CDDB8cdab210981
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xc65F7efcf78cB25C6424cEee30A9450Db53CdFFB
# Token: JARVIS
# Net PnL: $8.6176
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x2fD2F42fcFabA50EeaFa3413bCD8558D29676BF6
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x9c07a601C16D37068268f939231C367352F091A4
# Token: JARVIS
# Net PnL: $-42.0205
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x9922B2d92E9b3cA3FDc41326328F1D5a87D3232d
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 213.1205
# ============================================================
# ============================================================
# Trader: 0x8EC295AffCe8824e54b1f307bE1A38C2C2F0E0A5
# Token: JARVIS
# Net PnL: $-1.7287
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x67b6adc421B2aaB694406182A82d5f67172aB976
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 27444.7906
# ============================================================
# ============================================================
# Trader: 0xfb14e6423939C101CB4cA44afE950D84E7c97Fa8
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 48187.174
# ============================================================
# ============================================================
# Trader: 0x04f09D2b96f037Cc756931a79f193a6950dffd35
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xE039493466FB7A2a879f24D2544d859C3eB61Ddf
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 113728.4788
# ============================================================
# ============================================================
# Trader: 0x93Ee59B236fD1Af89619B3B420E4F96718EFE1fa
# Token: JARVIS
# Net PnL: $7.8923
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x8028bE0a226d59AEb1C1144ac8264aC28004241a
# Token: JARVIS
# Net PnL: $-6.3556
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x759B94E1EC056C769dFeF808dBD29995393c26C7
# Token: JARVIS
# Net PnL: $-0.4089
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD504decb1DB1C0cBe01B498E6F690B0dA49B100a
# Token: JARVIS
# Net PnL: $32.4961
# Remaining Tokens: 2813096.2886
# ============================================================
# ============================================================
# Trader: 0x23BED36178ebeEe4f0d0D5888a203B5F6453e3FF
# Token: JARVIS
# Net PnL: $85.2913
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xEFF023Bb006dA503414507062BB4B86291e8707f
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 436391.7792
# ============================================================
# ============================================================
# Trader: 0x097DE213534abc30abf1dcccEA99cEDC40cc0629
# Token: JARVIS
# Net PnL: $-941.2294
# Remaining Tokens: 790532.6282
# ============================================================
# ============================================================
# Trader: 0xb0a8B427EE85f03bfa78D278CCe007Cd90B31AAb
# Token: JARVIS
# Net PnL: $1.3071
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x5129e88DCEf2F6e41A4322398f8c4229f02D5c01
# Token: JARVIS
# Net PnL: $0.2901
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x09b5d7710872164E39085385E3563b7024BCA704
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4e192525ef62851877AC02e7ab82e34062635091
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3B2fF08B1E2dfA50267cCD34f1d846eF0482b5bc
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xA232317EB657A5484EeA7Ab73967AAEbb01762Cf
# Token: JARVIS
# Net PnL: $-5.9929
# Remaining Tokens: 230.5323
# ============================================================
# ============================================================
# Trader: 0x9eCDc342090E5943E81461E286EAFA61b0C46b17
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x45C9C6275405fffEadd48a7f8bf694e300ab7C42
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 16209.0777
# ============================================================
# ============================================================
# Trader: 0x18a6b805BBeE907c955Ce2328ce8931c3998902E
# Token: JARVIS
# Net PnL: $5.6883
# Remaining Tokens: 167211.0269
# ============================================================
# ============================================================
# Trader: 0xE7b27BD74F522afa05732ba82B2F46A38D4Be098
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 529400.4945
# ============================================================
# ============================================================
# Trader: 0x333daa0c134D183Cc7430B2bb13c5e39b9bc5a5E
# Token: JARVIS
# Net PnL: $-3.1323
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x62af8487A344c964b4438C15d3E51257610FB7d0
# Token: JARVIS
# Net PnL: $-3.2321
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x3401Dbe8C8CA02ac0F20AFc5bE5F00DDC7c44416
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 211.9637
# ============================================================
# ============================================================
# Trader: 0x5BA4a1B24C3fFF3a52AD19b0253e7f756C0e1a0c
# Token: JARVIS
# Net PnL: $-650.0196
# Remaining Tokens: 393.8794
# ============================================================
# ============================================================
# Trader: 0x0B3004bD9a1D39fA30cb138E7Ac4eF3467B3C029
# Token: JARVIS
# Net PnL: $0.6907
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x1929EBcB8f32587C7841367EC6B3be92427A1869
# Token: JARVIS
# Net PnL: $20.6099
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3C6Ec8Fb33537A487d097C4491d3D81AE43C5f9D
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2056.4509
# ============================================================
# ============================================================
# Trader: 0x8F7651Ed6d6Add5b2e2635E9F4E938DD8020e35B
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x5CB48b953B123DF3211BF11ba7210cD54e230f11
# Token: JARVIS
# Net PnL: $-1.3341
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xEFf18a352991d281b43BFD793e46c70E9AF61bDf
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 556.1609
# ============================================================
# ============================================================
# Trader: 0x522621117404D022212c359cb2f46b0606255d02
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 307983.0501
# ============================================================
# ============================================================
# Trader: 0x603d880Fb750d000Bf2291D1cB25f15E0B4Cf40e
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3833049aC14f751c13F67e91f954393e655A7915
# Token: JARVIS
# Net PnL: $0.8603
# Remaining Tokens: 41.141
# ============================================================
# ============================================================
# Trader: 0xd6474F2D929a8D5e4aD44CFACf48db28081110Ff
# Token: JARVIS
# Net PnL: $-6.2017
# Remaining Tokens: 53.8573
# ============================================================
# ============================================================
# Trader: 0xac3f081b98d076FA64A7c784c5b330e40F1202aD
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2055.2275
# ============================================================
# ============================================================
# Trader: 0xf6AF7F0BB1c5a88E00aA97bEC66f23fC5B53D3D5
# Token: JARVIS
# Net PnL: $11.1917
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3aF8607045010bbE061F91E7110B02dCFCCA15c0
# Token: JARVIS
# Net PnL: $10.2316
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x4A83e6dA1B13f157cc9636243589e5b64F965785
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 5002.6486
# ============================================================
# ============================================================
# Trader: 0x0619e9C5e7AC9f1C831eDDEA02F4b19f32A7D272
# Token: JARVIS
# Net PnL: $23.6306
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x11a0e53ACB33ac9811b02833Eaea2D076a199747
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 19966.7956
# ============================================================
# ============================================================
# Trader: 0x00b36398D806247D7365315a3281Fa1747f988Af
# Token: JARVIS
# Net PnL: $-0.0004
# Remaining Tokens: 240.5659
# ============================================================
# ============================================================
# Trader: 0xee7091C7C3266FAA43e9C79BEb95AD5396A80bd1
# Token: JARVIS
# Net PnL: $-2.346
# Remaining Tokens: 6581.3368
# ============================================================
# ============================================================
# Trader: 0x7c3f49A46599d20262ef52Cc1BC81bd29B24F6Ec
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4d862F3662e5Cf26b2C931c83A15006Ed75f0b45
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xb530F365505dB78C3cB883226e1A94Aae318671F
# Token: JARVIS
# Net PnL: $-1.0045
# Remaining Tokens: 826.2233
# ============================================================
# ============================================================
# Trader: 0xE08D9cc9b651cB95dE82562a3642AfE7c7CDb902
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 2062.898
# ============================================================
# ============================================================
# Trader: 0xdF31c821BA198E0CcfC379599B799CAD37225327
# Token: JARVIS
# Net PnL: $-5.0901
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x7738A732529A253b25DD9942873d74CdCbd58c05
# Token: JARVIS
# Net PnL: $11.8519
# Remaining Tokens: 1801.8252
# ============================================================
# ============================================================
# Trader: 0x1c7EA45D1778ab800ee200e53863966C68c34e6c
# Token: JARVIS
# Net PnL: $-21.1879
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xC0AF6f3aF49e5C811E9c4C3240a8d399A81dA158
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 7203.86
# ============================================================
# ============================================================
# Trader: 0xA10403616a5201f5a9Bfc25C1fE129594AEaB579
# Token: JARVIS
# Net PnL: $-6.7456
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xFF9494895962373266F763d37C07E5fb1eB7e1fB
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 411211.4786
# ============================================================
# ============================================================
# Trader: 0xCD60153384818fdCb5eE9f549ffBFF4fCCBd037e
# Token: JARVIS
# Net PnL: $-29.4035
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4b4F3AE277af82B4eCa97236504574a1AFE534fB
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4089.2566
# ============================================================
# ============================================================
# Trader: 0x0a1ac7d31142760c430d0bb7C801c3C727A81d69
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 61147.0952
# ============================================================
# ============================================================
# Trader: 0x391E7c51A8F57fbad8320cc9b3C95D2AC41617c2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 204.2135
# ============================================================
# ============================================================
# Trader: 0x2e037d8147B151e321f14Ac595fe2330e6dcc3F2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 10209.6523
# ============================================================
# ============================================================
# Trader: 0x4C27033984B9cC77A9877D0CBe27D2C029f06F38
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 9544.6682
# ============================================================
# ============================================================
# Trader: 0x40171a02b16E1F82Ae20154E3d9E68FCC0e233D9
# Token: JARVIS
# Net PnL: $-10.7755
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x7562884a4E561A7434E503Da00ABaF6FBF2ac194
# Token: JARVIS
# Net PnL: $29.5058
# Remaining Tokens: 12647.2213
# ============================================================
# ============================================================
# Trader: 0x8D47bA07Ff9ccCCF58c7E8810eE42c0Dc8B8b123
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x6b2Ee939b41E051A0439A79E6B39B90Ce1ce75e7
# Token: JARVIS
# Net PnL: $5.235
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x24A941E2aD8622Ba222754125CfbE86A9d6B1198
# Token: JARVIS
# Net PnL: $-0.0899
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x361B133c3b6D48e75da763f07b7fE70e28b300A3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xB9740184Cf59D5aa7b36Abf9Fc4A04e0635DAe4A
# Token: JARVIS
# Net PnL: $1.3506
# Remaining Tokens: 1.2633
# ============================================================
# ============================================================
# Trader: 0xA2C6a6fCE83B70fba15Ab938947A5321D7a210E8
# Token: JARVIS
# Net PnL: $-2.686
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x80084A56F2344a1d6266ac0b9547EA517DB37979
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xDAe5F1a2bbf141d099101Dc054F41b48D8c5C207
# Token: JARVIS
# Net PnL: $-44.0108
# Remaining Tokens: 3663.8976
# ============================================================
# ============================================================
# Trader: 0x4B8e354DCB3dfAa43504f06afa5063DfD913C7B5
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 210.4027
# ============================================================
# ============================================================
# Trader: 0xfa8218f112D1e410c63476ff0e731cb3C490445F
# Token: JARVIS
# Net PnL: $-2400.5386
# Remaining Tokens: 17143.2078
# ============================================================
# ============================================================
# Trader: 0xBB79289aEc697Ab65d13Dc8411BE220C9498d1C0
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 10170.1417
# ============================================================
# ============================================================
# Trader: 0x50f6B4420ABfBe9129d1aA88B42B87E8D1f7925b
# Token: JARVIS
# Net PnL: $-0.4832
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xC3C4baD872A4CC0Ef52cd0c35fb354C8Da7F3700
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 203.3736
# ============================================================
# ============================================================
# Trader: 0xcc6F3C06768B6ab99E44d0859dea722322033c69
# Token: JARVIS
# Net PnL: $-34.1554
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xf2a37Fc9F4699e5395e29960a98C53f2f383C353
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x07CA192B4cDB8c67b0e491Bb133056c3e9dD4027
# Token: JARVIS
# Net PnL: $10.4748
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0xa32e7105529bf64abFA22F4DCc0D7E13Aff4cF4b
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x55f2d064C6851Ae635aE15DDE2dFdEe88A1D34FA
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 8667.2222
# ============================================================
# ============================================================
# Trader: 0x5995C29dF40045CBa7d7f9125e956380C896010b
# Token: JARVIS
# Net PnL: $-9.2265
# Remaining Tokens: 185.2566
# ============================================================
# ============================================================
# Trader: 0x3B35ed11C906EFF72d4326c5a101738FA3751e55
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD07ff359d4D855b23Efc77dAed3FD1419900d071
# Token: JARVIS
# Net PnL: $-35.49
# Remaining Tokens: 0.0
# ============================================================
# ============================================================
# Trader: 0x0FdF8675930649093070FCeC193679B675Ec2E20
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x14E4151A8980d7CaDBE13dfBc6b519e53480bDf1
# Token: JARVIS
# Net PnL: $0.7714
# Remaining Tokens: 268.0614
# ...
# Trader: 0x7aC48adE771817025e117c3dE6254c7f02eE6a4A
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 83559.3541
# ============================================================
# ============================================================
# Trader: 0xfa0540ef4f5BDda2F248DbE4fD5691B41b787beA
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x242B9d7bf767CD2FeEf8E49533a8f2F64a11599d
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 413.8849
# ============================================================
# ============================================================
# Trader: 0x5531175bC0f98704Ce1Dc60aEAbfDf56fEb518F3
# Token: JARVIS
# Net PnL: $-0.1868
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x8fCF4dc0F0F542b7a44ebFaDe723077070eb67F9
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x28a48d16D5E8D79F6de73f2c1b3B9e423f95B9F5
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xB6f52520235FDA99D8C7387Ac35E6956F5c4C0a3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x6353D12968C3aEaF23E0aE7CCDa23a6846E9537A
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x0E0160a77a40cF11D0e43fE1f86752F0BE3d2110
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd1EB3C5ECCBce93Ef2802F7edb3710e5116b6c8F
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x2Ef895BEDC8dAe333BEDeC053C37aD106097FB8c
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 21444.2374
# ============================================================
# ============================================================
# Trader: 0x48D2a152B418A9c9E9779Ab647Ec00D0b5D0C7b7
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xc194d220F418976A17Bf5273eF58f282fD7Bef6B
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 49569.0835
# ============================================================
# ============================================================
# Trader: 0x811972642Ad4dC0445Aa76B74B755fB261C02138
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xDb59dd5A1e02645908746fd4Dac69734A8559f6E
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x5aA0e963107E2F8e7bc5A98BCa3CfC1fc072f617
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD52427870052d7d0Ab0c1c8cB006dF84D1Fb8c88
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3E97C6aF271fEF87bE2a25647c6D2675C40D6C0E
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x112630bA98300A8FB0aF4EdDB42449c03fC65a58
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd68Dda66C30661514746C4b09d746cF905BAafF7
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD24425e7D3C239d7fBA892E19899bcDc4322eedd
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xF75D77c3c8B4aFa311B6383E759A766BC346Bb56
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x41Bf8DdaD243518B7E50A8e572FE95708Af8d88D
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x85707B4d7203a0DF7D5AF64214F50d1bFc348858
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x9898a638Ad5a403EE3DcCF576Cb063c34510234f
# Token: JARVIS
# Net PnL: $-0.0882
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4753103E164040A3ca128092a2671c9dBC07e9d5
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xeDb297FfF58fA0857606a22BeaAC48Bd226168bf
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xe45745C3a45985653AbA455e8986e5AE7E0d79F1
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x87534d00B9B5aaB6dee6bCf254F207b85f5d8611
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x7F812A524E72461B4AA20f3146A0b3C50271Efbf
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xd064f596C9039d0e8A6eDaFafd41131F98b80363
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x0dA42490C4D1c8dd6D6e1164F6Dd21a4Bb21A8db
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xf0d7f44378B2A825E3F61151D9Fb0C444A0930FC
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 4335.4802
# ============================================================
# ============================================================
# Trader: 0x264C8A5B01D884c8fAE014e082AF816FdB3a21Cc
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x91924c8A9e3962C9023BB3873DC7A1DebbCd4F6e
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 43233.4951
# ============================================================
# ============================================================
# Trader: 0x4C0fff9f2436b58421e7554F9Aa7EfDcc2859394
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xf90173aA266b1f07C8cbaa504DA6c3Ba29ed0741
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xB2ce2bdaF175D49D78b9B995eE92Aa0110043983
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x41f5787F088Cf4B906271aA7136984247D07d590
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x40F3a6c0066792922114052faeA716a9013f72a2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xef9b45991D1103327A865e409E967D19a5C024fE
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x2B8bfe13d8D22595d7B214B4e5b94E766060f916
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 957.0614
# ============================================================
# ============================================================
# Trader: 0xEAbF2274151C23c6988b722569292647FC3F642a
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x6f9c30621C8774514a7753dDCf9619394fabdc09
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xad8734d1C29C4c66Ab71EEAce5E0B3bBEE43B2aB
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x45002041B8bE82Ac648C9d1e0ed4AF3C4C719d32
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x901Ad05A923Dde1a657734Ce484382B919D5Df28
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x8a1BDd5D6c7c42Bc52Edfca1EB445b9ed99415B9
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xA87e83242b5f8A8903b48b353e417F252DD5389C
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x2Cbf5A5736358103C187F7f6BB0fb8Da5109C205
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x21F4619eD67dff36ae79BF84C8374437Be94cF34
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1D50802f0bce221aB26574A4102696456C1CD2a3
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 24274.3577
# ============================================================
# ============================================================
# Trader: 0x00c3Bdf8604bc11ad45fc7B9Eb54dDA07f46d3AF
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x4d69FC080700395413b42085D0Bb1a0B3632b4ee
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 6314.272
# ============================================================
# ============================================================
# Trader: 0x7398CbE1DdEd22E23dFa1796b5e4166535AB23cD
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xBA697980c4Cd197B6660962Ef8f7b809097252d1
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 971.7284
# ============================================================
# ============================================================
# Trader: 0xae3Faa6aE4c57f3C65C426330e0E374D135c0f83
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x87047f8A5D1b8C8e7F84cE6F4079D2c586b1eb4A
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xCAC0D9CF566C49b0E42d006494EEde41d72d77a2
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 1031.2063
# ============================================================
# ============================================================
# Trader: 0xea7e65451ED052986790843B92cA8E6Bef2Be9AF
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x2c04919988A49829559bb9d175b468C6F2542176
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x66bA596F313b366df6dEB088837650b475509a4a
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x06c105C669bBbB2525dAA5635d62D3A7f4294eFc
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xB3B1BCB3c78a9D2220AC56812A0E28CB7abB5A73
# Token: JARVIS
# Net PnL: $-1.0246
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xE21c5b8AA46662475baFE4B826A12402789fE3f0
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x1d4500f39c83772210D5Eac5382121161BD0f0D1
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xC864518c4075424Ab373ed89A0C08f656815464a
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xe67f4831D7C98cf8B0aF233154D6E405C62567B4
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x9195bCD64d01C55a495f67364fF1d24C9df59540
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x3f6F17a0dc4C4b91f379EF39709eE4C45A826652
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0xD9924F2D904152201E0F8413F81BE92D4706a4a1
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
# ============================================================
# Trader: 0x35e5c8D4861bDB5De4D5F32966143BEaed3E3D92
# Token: JARVIS
# Net PnL: $0.0
# Remaining Tokens: 0
# ============================================================
